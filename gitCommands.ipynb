# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks/Data Science and Business Analytics - Spark Internship
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Data Science and Business Analytics - Spark Internship

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/Data Science and Business Analytics - Spark Internship

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/MyDrive/Colab Notebooks/Data Science and Business Analytics - Spark Internship/.git/

# %%
# !git remote add origin https://arutprakash:Reflection2am@github.com/arutprakash/Data-Science-and-Business-Analytics.git
# !git remote -v
# Out:
# origin	https://arutprakash:Reflection2am@github.com/arutprakash/Data-Science-and-Business-Analytics.git (fetch)
# origin	https://arutprakash:Reflection2am@github.com/arutprakash/Data-Science-and-Business-Analytics.git (push)

# %%
# !git config --global user.email 'arutprakash2000@gmail.com'
# !git config --global user.name 'arutprakash'

# %%
# !git add .
# !git commit -m 'Task One'
# Out:
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# fatal: not a git repository (or any parent up to mount point /content)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git push origin master
# Out:
# fatal: unable to access 'https://arutprakash:Prakash2000@@github.com/arutprakash/{Data-Science-and-Business-Analytics}.git/': Could not resolve host: @github.com
